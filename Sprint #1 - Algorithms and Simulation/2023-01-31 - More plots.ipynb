# %%
# %matplotlib inline
from pylab import *
from sci378 import *
# Out:
# Version:  0.0.25

# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/bblais/Documents/Git/Computer-Programming-for-the-Sciences-Spring-2023/Sprint #1 - Algorithms and Simulation'

# %%
data=pd.read_excel('data/object1_data.xlsx')
data
# Out:
#     Unnamed: 0      t      y
# 0            0  0.000  2.000
# 1            1  0.022  2.000
# 2            2  0.042  1.986
# 3            3  0.065  1.977
# 4            4  0.082  1.958
# 5            5  0.099  1.930
# 6            6  0.122  1.906
# 7            7  0.145  1.883
# 8            8  0.159  1.850
# 9            9  0.179  1.817
# 10          10  0.202  1.774
# 11          11  0.219  1.732
# 12          12  0.242  1.680
# 13          13  0.262  1.633
# 14          14  0.282  1.581
# 15          15  0.304  1.520
# 16          16  0.319  1.459
# 17          17  0.339  1.393
# 18          18  0.364  1.322
# 19          19  0.384  1.247
# 20          20  0.404  1.167
# 21          21  0.421  1.087
# 22          22  0.444  0.997
# 23          23  0.464  0.903
# 24          24  0.484  0.823
# 25          25  0.504  0.715
# 26          26  0.521  0.626
# 27          27  0.547  0.522
# 28          28  0.561  0.418
# 29          29  0.581  0.291

# %%
data=pd.read_excel('/Users/bblais/Documents/Git/Computer-Programming-for-the-Sciences-Spring-2023/Sprint #1 - Algorithms and Simulation/data/object1_data.xlsx')
data
# Out:
#     Unnamed: 0      t      y
# 0            0  0.000  2.000
# 1            1  0.022  2.000
# 2            2  0.042  1.986
# 3            3  0.065  1.977
# 4            4  0.082  1.958
# 5            5  0.099  1.930
# 6            6  0.122  1.906
# 7            7  0.145  1.883
# 8            8  0.159  1.850
# 9            9  0.179  1.817
# 10          10  0.202  1.774
# 11          11  0.219  1.732
# 12          12  0.242  1.680
# 13          13  0.262  1.633
# 14          14  0.282  1.581
# 15          15  0.304  1.520
# 16          16  0.319  1.459
# 17          17  0.339  1.393
# 18          18  0.364  1.322
# 19          19  0.384  1.247
# 20          20  0.404  1.167
# 21          21  0.421  1.087
# 22          22  0.444  0.997
# 23          23  0.464  0.903
# 24          24  0.484  0.823
# 25          25  0.504  0.715
# 26          26  0.521  0.626
# 27          27  0.547  0.522
# 28          28  0.561  0.418
# 29          29  0.581  0.291

# %%
t=array(data['t'])
y=array(data['y'])

# %%
t,y
# Out:
# (array([0.   , 0.022, 0.042, 0.065, 0.082, 0.099, 0.122, 0.145, 0.159,
#         0.179, 0.202, 0.219, 0.242, 0.262, 0.282, 0.304, 0.319, 0.339,
#         0.364, 0.384, 0.404, 0.421, 0.444, 0.464, 0.484, 0.504, 0.521,
#         0.547, 0.561, 0.581]),
#  array([2.   , 2.   , 1.986, 1.977, 1.958, 1.93 , 1.906, 1.883, 1.85 ,
#         1.817, 1.774, 1.732, 1.68 , 1.633, 1.581, 1.52 , 1.459, 1.393,
#         1.322, 1.247, 1.167, 1.087, 0.997, 0.903, 0.823, 0.715, 0.626,
#         0.522, 0.418, 0.291]))

# %%
t_model=linspace(0,.6,100)
y_model=-3*t_model+2

plot(t,y,'o')
plot(t_model,y_model,'-')
