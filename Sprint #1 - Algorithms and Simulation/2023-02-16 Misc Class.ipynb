# %%
# %matplotlib inline
from pylab import *
from sci378 import *
# Out:
# Version:  0.0.25

# %%
x=linspace(10,30,100)

y1=randn(len(x))
y2=randn(len(x))+100


plot(x,y1,'o')
plot(x,y2,'s')

# %%
x=linspace(10,30,100)

y1=randn(len(x))
y2=randn(len(x))+100

subplot(2,1,1)
plot(x,y1,'o')
subplot(2,1,2)
plot(x,y2,'s')

# %%
x=linspace(10,30,100)

y1=randn(len(x))
y2=randn(len(x))+100

plot(x,y1,'bo-')
twinx()
plot(x,y2,'rs-')
