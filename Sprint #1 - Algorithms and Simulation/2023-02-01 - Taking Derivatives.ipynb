# %%
# %matplotlib inline
from pylab import *
from sci378 import *
# Out:
# Version:  0.0.25

# %%
def fun(x):
    return x**2-10*x+11

# %%
pwd
# Out:
# '/Users/bblais/tex/bryant/spring_2023/computer_programming_378/python'

# %%
fun(-1)
# Out:
# 22

# %%
linspace(-5,15,11)
# Out:
# array([-5., -3., -1.,  1.,  3.,  5.,  7.,  9., 11., 13., 15.])

# %%
fun(linspace(-5,15,11))
# Out:
# array([ 86.,  50.,  22.,   2., -10., -14., -10.,   2.,  22.,  50.,  86.])

# %%
figure(figsize=(6,4))
x=linspace(-5,15,100)
y=fun(x)
plot(x,y)

# %%
figure(figsize=(6,4))
x=linspace(-5,15,20)
y=fun(x)
plot(x,y,'o')

# %% [markdown]
# ## derivative
#
# - run through each x value
# - get the function a little bit to the left and to the right
# - calculate the slope -- rise/run
# - keep a record of each of these calculation (collecting all of the individual calc into array)

# %%
x_start=-5
x_end=15
step=0.1

S=Storage()

x=x_start
while x<=x_end:
    
    #print(x," ",end="")
    
    y_left=fun(x-step/2)
    y_right=fun(x+step/2)
    
    m=(y_right-y_left)/(step)
    
    S+=x,m
    
    x=x+step
    
print("done.")

x,m=S.arrays()
# Out:
# done.

# %%
figure(figsize=(6,4))

plot(x,m)

x_expected=linspace(-5,15,100)
y_expected=2*(x_expected-5)

plot(x_expected,y_expected,'r--')

# %% [markdown]
# ## integral
#
# - run through each x value
# - get the function a little bit to the left and to the right
# - calculate the area -- rectangle and a triangle
# - keep a record of each of these calculation (collecting all of the individual calc into array)

# %% [markdown]
# ## zeros
#
#
# - run through each x value
# - get the function a little bit to the left and to the right
# - check the sign -- if signs are the same, then if we multiply them we get 1, if prod signs not equal 1, then zero
# - keep a record of each of these calculation (collecting all of the individual calc into array)

# %%
sign(-5)
# Out:
# -1

# %%
sign(9)
# Out:
# 1
